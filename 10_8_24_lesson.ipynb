# %% [markdown]
# <a href="https://colab.research.google.com/github/girta79/WoTech_Python_Individual_Work/blob/main/10_8_24_lesson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lesson 16.**
#
# Topic:
#
# **Project 1: Pokemon dataset analysis || (Pokémon data analysis using scatter plots, correlations, and correlation matrices. We start using the Seaborn library) 👩‍💻**
#
# 1. Continuing work with first project: Pokemon data analysis
# 2. Understand how to analyze correlations in Pandas DataFrames
# 3. Creating scatter plots to evaluate the relationship between two variables
# 4. Understanding the difference between correlation and causation
# 5. Creating and visualizing correlation matrix with Seaborn library
#
#
# Teamwork:
# Task: Visualizing the correlation of Attack and Defense variables of two Types: Grass and Water Type 1 Pokémon.
# 1. Create two DataFrame Grass and Water
# 2. Create the regression plots for each (Grass and Water)
# 3. Calculate the Pearson correlation for each DataFrame (variables: Attack and Defense)
# 4. Explain to each other what do you see and what it means.

# %%
# LESSON 10.8.24

# %%
import pandas as pd
import matplotlib.pyplot as plt
pokemon_df = pd.read_csv('/content/Pokemon.csv')

# pandas documentation - look in google
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html

# %%
pokemon_df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# create a histogram of column 'Speed'

plt.hist(pokemon_df['Speed'], color = 'green', edgecolor = 'black')
plt.xlabel('Total')
plt.ylabel('Frequency')
plt.title('Histogram of Pokemon Speeds')

# add to your histogram min, max, mean (average) lines

plt.axvline(pokemon_df["Speed"].mean(), color='grey', linestyle='dashdot', linewidth=1)
plt.axvline(pokemon_df["Speed"].max(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(pokemon_df["Speed"].min(), color='blue', linestyle='dashed', linewidth=1)

# %%
min - max

kood puudu!

# %% [markdown]
# # CORRELATIONS

# %%
# scatter plot between variables: Attack and Defense

plt.scatter(pokemon_df['Attack'], pokemon_df['Defense'], color='blue', alpha=0.5)
plt.title('Attack vs. Defense')
plt.xlabel('Attack')
plt.ylabel('Defense')
# Out:
# Text(0, 0.5, 'Defense')

# %%
# scatterplot for variables: Speed and Defense

plt.scatter(pokemon_df['Speed'], pokemon_df['Defense'], color='red', alpha=0.5)
plt.xlabel('Speed')
plt.ylabel('Defense')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
# add screenshot

from IPython.display import Image
path = '/content/correlation.png'

# display the screenshot
Image(filename=path)

# %%
# scatterplot for variables: HP and Defense

plt.scatter(pokemon_df['HP'], pokemon_df['Defense'], color='green', alpha=0.5)
plt.xlabel('HP')
plt.ylabel('Defense')
plt.title('Scatter plot')
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %% [markdown]
# # Pearson correlation

# %% [markdown]
# The correlation coefficient indicates the strength and direction of the statistical relationship between two variables. The coefficient ranges from -1 to 1, with a value of 0.43 signifying a positive but moderately strong relationship between the two variables.
#
# - A positive correlation coefficient means that the variables increase together. Therefore, as one variable increases, the other also tends to increase, and vice versa.
#
# The closer the correlation coefficient is to 1, the stronger the positive relationship.
#
# - A correlation coefficient of 0.43 is not very high, but it indicates a moderately positive relationship.
#
# If the correlation coefficient were negative, it would suggest that as one variable increases, the other variable decreases.
# - A correlation coefficient of -1 indicates a perfect negative relationship.
#
# Thus, a correlation coefficient of 0.43 might suggest that, for example, as Pokémon's Attack values increase, their Defense values tend to increase as well, but the relationship is not very strong.

# %%
# result of this correlation calculation is between -1 and 1.
# -1 perfect negative relationship
# 1 perfect positive relationship

# %%
# Pearson correlation between Attack/Defense

correlation1 = pokemon_df['Attack'].corr(pokemon_df['Defense'])
correlation1
# Out:
# 0.4386870551184892

# %%
# Pearson correlation between Speed/Defense

correlation2 = pokemon_df['Speed'].corr(pokemon_df['Defense'])
correlation2
# Out:
# 0.015226598088597448

# %%
# select only numeric colums

numeric_colums = pokemon_df.select_dtypes(include=['number'])
numeric_colums = numeric_colums.drop('#', axis=1)

numeric_colums
# Out:
#      Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0      318  45      49       49       65       65     45           1
# 1      405  60      62       63       80       80     60           1
# 2      525  80      82       83      100      100     80           1
# 3      625  80     100      123      122      120     80           1
# 4      309  39      52       43       60       50     65           1
# ..     ...  ..     ...      ...      ...      ...    ...         ...
# 795    600  50     100      150      100      150     50           6
# 796    700  50     160      110      160      110    110           6
# 797    600  80     110       60      150      130     70           6
# 798    680  80     160       60      170      130     80           6
# 799    600  80     110      120      130       90     70           6
#
# [800 rows x 8 columns]

# %%
target_column  = 'Attack'
correlation_result = {} #key = column, val =pearson_correlation

# for loop comparing target column and all other columns  in the Dataframe

for col in numeric_colums.columns:
    correlation = pokemon_df[target_column].corr(pokemon_df[col])
    correlation_result[col] = correlation

correlation_result
# Out:
# {'Total': 0.7362106519949293,
#  'HP': 0.422386028776223,
#  'Attack': 1.0,
#  'Defense': 0.4386870551184892,
#  'Sp. Atk': 0.396361755349232,
#  'Sp. Def': 0.26398955110108846,
#  'Speed': 0.38123973924108967,
#  'Generation': 0.051451336708469686}

# %%
# Select only numeric columns

numeric_columns = pokemon_df.select_dtypes(include=['number'])
numeric_columns = numeric_columns.drop('#', axis=1)
numeric_columns
target_column = 'Attack'
correlation_results = {} #key = column, val=pearson_correlation

# for loop comparing target column and all other columns in the DataFrame

for col in numeric_columns.columns:
  if col =='Attack':
    continue
  correlation = pokemon_df[target_column].corr(pokemon_df[col])
  correlation_results[col] = correlation

correlation_results
# Out:
# {'Total': 0.7362106519949293,
#  'HP': 0.422386028776223,
#  'Defense': 0.4386870551184892,
#  'Sp. Atk': 0.396361755349232,
#  'Sp. Def': 0.26398955110108846,
#  'Speed': 0.38123973924108967,
#  'Generation': 0.051451336708469686}

# %% [markdown]
# # Correlation matrix

# %%
correlation_matrix = numeric_colums.corr() # all columns are numeric
correlation_matrix
# Out:
#                Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total       1.000000  0.618748  0.736211  0.612787  0.747250  0.717609
# HP          0.618748  1.000000  0.422386  0.239622  0.362380  0.378718
# Attack      0.736211  0.422386  1.000000  0.438687  0.396362  0.263990
# Defense     0.612787  0.239622  0.438687  1.000000  0.223549  0.510747
# Sp. Atk     0.747250  0.362380  0.396362  0.223549  1.000000  0.506121
# Sp. Def     0.717609  0.378718  0.263990  0.510747  0.506121  1.000000
# Speed       0.575943  0.175952  0.381240  0.015227  0.473018  0.259133
# Generation  0.048384  0.058683  0.051451  0.042419  0.036437  0.028486
#
#                Speed  Generation
# Total       0.575943    0.048384
# HP          0.175952    0.058683
# Attack      0.381240    0.051451
# Defense     0.015227    0.042419
# Sp. Atk     0.473018    0.036437
# Sp. Def     0.259133    0.028486
# Speed       1.000000   -0.023121
# Generation -0.023121    1.000000

# %% [markdown]
# # Visualizing with seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(correlation_matrix, annot = True) # annotation - adding values
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(correlation_matrix, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="inferno") #annotation -adding values
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, cmap = "Pastel1", annot = True)
plt.title("Correlation matrix")
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %% [markdown]
# https://www.tylervigen.com/spurious-correlations

# %% [markdown]
# # Linear regression (predict one value based on the other)

# %%
sns.regplot(x = 'Attack', y='Defense', data=pokemon_df)
plt.show()

sns.regplot(x = 'Attack', y='Defense', data=pokemon_df, fit_reg=False)
plt.show()

# %%
# sns.regplot(x = 'Attack', y='Defense', data=pokemon_df)

sns.regplot(
    data=pokemon_df, x='Attack', y="Defense",
    ci=99, marker="x", color=".3", line_kws=dict(color="r"),
)
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %%
sns.regplot(
    data=pokemon_df, x='Speed', y="Defense",
    ci=99, marker="x", color=".3", line_kws=dict(color="r"),
)

correlation2 = pokemon_df['Speed'].corr(pokemon_df['Defense'])
print('Pearson correlation coefficient:', correlation2)
# Out:
# Pearson correlation coefficient: 0.015226598088597448

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.regplot.html

# %%
sns.regplot(x='Speed', y='Defense', data=pokemon_df, color='purple', ci=99, marker='x', line_kws={'color':'red'})
plt.title('Speed vs Defense')
plt.xlabel('Speed')
plt.ylabel('Defense')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
pokemon_df = pd.read_csv('/content/Pokemon.csv')

# Create DataFrames for Grass and Water Type 1 Pokémon
grass_df = pokemon_df[pokemon_df['Type 1'] == 'Grass']
water_df = pokemon_df[pokemon_df['Type 1'] == 'Water']

# Regression plot for Grass Type 1 Pokémon
plt.figure(figsize=(10, 6))
sns.regplot(x='Attack', y='Defense', data=grass_df, color='green')
plt.title('Attack vs. Defense for Grass Type 1 Pokémon')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.show()

# Regression plot for Water Type 1 Pokémon
plt.figure(figsize=(10, 6))
sns.regplot(x='Attack', y='Defense', data=water_df, color='blue')
plt.title('Attack vs. Defense for Water Type 1 Pokémon')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.show()

# Calculate Pearson correlation for Grass Type 1 Pokémon
grass_correlation = grass_df['Attack'].corr(grass_df['Defense'])
print(f'Pearson correlation for Grass Type 1 Pokémon (Attack vs. Defense): {grass_correlation:.2f}')

# Calculate Pearson correlation for Water Type 1 Pokémon
water_correlation = water_df['Attack'].corr(water_df['Defense'])
print(f'Pearson correlation for Water Type 1 Pokémon (Attack vs. Defense): {water_correlation:.2f}')

# %% [markdown]
# # Explanation
# 1. Creating DataFrames for Grass and Water Type 1 Pokémon:
# - We first filter the original pokemon_df DataFrame to create two new DataFrames: grass_df for Grass Type 1 Pokémon and water_df for Water Type 1 Pokémon.
#
# - grass_df contains all rows where the 'Type 1' column is 'Grass'.
# - water_df contains all rows where the 'Type 1' column is 'Water'
#
# 2. Regression Plots:
# - We use Seaborn's regplot function to create scatter plots with regression lines to visualize the relationship between Attack and Defense variables for both Grass and Water Type 1 Pokémon.
# - The first plot shows the relationship for Grass Type 1 Pokémon, with points and the regression line in green.
# - The second plot shows the relationship for Water Type 1 Pokémon, with points and the regression line in blue.
# 3. Calculating Pearson Correlation:
# - We calculate the Pearson correlation coefficient for the Attack and Defense variables in both grass_df and water_df.
# - The Pearson correlation coefficient is a measure of the linear relationship between two variables, ranging from -1 to 1.
#   - A positive value indicates a positive relationship: as one variable increases, the other also tends to increase.
#   - A negative value indicates a negative relationship: as one variable increases, the other tends to decrease.
#   - A value close to 0 indicates a weak or no linear relationship.
# 4. Results:
# - For Grass Type 1 Pokémon, the Pearson correlation coefficient between Attack and Defense is printed.
# - For Water Type 1 Pokémon, the Pearson correlation coefficient between Attack and Defense is also printed.
#
#
# # What Do You See and What It Means:
# 1. Grass Type 1 Pokémon:
# - The regression plot shows the relationship between Attack and Defense. If the points are more spread out, the correlation is weaker. If they are closer to the regression line, the correlation is stronger.
# - The Pearson correlation coefficient tells us the strength and direction of this relationship. A positive value indicates that as Attack increases, Defense also tends to increase.
# 2. Water Type 1 Pokémon:
# - Similar to the Grass Type, the regression plot shows the relationship between Attack and Defense for Water Type 1 Pokémon.
# - The Pearson correlation coefficient provides the strength and direction of this relationship. A positive value indicates a positive relationship between Attack and Defense.
